# %% [markdown]
# # Guia para a biblioteca `datetime` em Python
#
# A biblioteca `datetime` em Python fornece objetos para manipulação de datas e horas. Aqui está um guia simples para algumas das funções mais úteis deste módulo.

# %% [markdown]
# ## datetime.datetime.strftime()
#
# A função `strftime()` converte um objeto datetime para uma string de acordo com um formato específico.
#
# Símbolos que podem ser usados para formatar datas podem ser achados [aqui](https://docs.python.org/3/library/datetime.html#strftime-and-strptime-format-codes).

# %%
from datetime import datetime
import locale

locale.setlocale(locale.LC_TIME, "pt_BR")

data_inicio = datetime(2026, 2, 15)

data_inicio_texto = data_inicio.strftime("%d de %B de %Y, %A")
print(data_inicio_texto)
# Out:
# 15 de fevereiro de 2026, domingo

# %% [markdown]
# ## datetime.datetime.strptime()
#
# A função `strptime()` analisa uma string representando uma data e hora de acordo com um formato. O retorno é um objeto datetime.

# %%
data_inicio_texto = "15 de fevereiro de 2026 às 15:25"
data_inicio = datetime.strptime(data_inicio_texto, "%d de %B de %Y às %H:%M")
print(data_inicio)
# Out:
# 2026-02-15 15:25:00

# %% [markdown]
# ## Trabalhando com fuso horário
#
# Podemos criar um objeto datetime usando a classe `datetime`. O construtor da classe aceita os seguintes argumentos:
#
# - `year`: ano (por exemplo, 2023)
# - `month`: mês (1-12)
# - `day`: dia (1-31)
# - `hour`: hora (0-23)
# - `minute`: minuto (0-59)
# - `second`: segundo (0-59)
# - `microsecond`: microssegundo (0-999999)
# - `tzinfo`: fuso horário

# %%
data_inicio = datetime(2026, 2, 15, 15, 25)
print(data_inicio)
# Out:
# 2026-02-15 15:25:00

# %% [markdown]
# Os horários que vimos até o momento são os que chamamos de ingênuos (*naive*). Eles não possuem informações sobre o fuso horário. Para criar um horário consciente (*aware*), precisamos passar um objeto `tzinfo` para o construtor da classe `datetime`. O módulo `datetime` fornece uma classe `timezone` que pode ser usada para criar um objeto `tzinfo`. No exemplo abaixo, usamos UTC como fuso horário. UTC significa Tempo Universal Coordenado, que é o fuso horário de referência a partir do qual todos os outros fusos horários são calculados.
#
# ![UTC](https://upload.wikimedia.org/wikipedia/commons/thumb/8/88/World_Time_Zones_Map.png/800px-World_Time_Zones_Map.png)

# %%
from datetime import datetime, timezone

fuso_horario = timezone.utc
data_inicio1 = datetime(2026, 2, 15, 15, 25, tzinfo=fuso_horario)
print(data_inicio)
# Out:
# 2026-02-15 15:25:00+00:00

# %% [markdown]
# Podemos passar um objeto `timedelta` para o construtor da classe `timezone` para criar um fuso horário com um deslocamento específico. Por exemplo, o código abaixo cria um fuso horário com um deslocamento de 3 horas em relação ao UTC:

# %%
from datetime import datetime, timezone, timedelta

fuso_horario_sp = timezone(timedelta(hours=-3))
data_inicio2 = datetime(2026, 2, 15, 15, 25, tzinfo=fuso_horario_sp)
print(data_inicio)
# Out:
# 2026-02-15 15:25:00-03:00

# %%
fuso_horario_ny = timezone(timedelta(hours=-4))
data_inicio2_fuso_ny = data_inicio2.astimezone(fuso_horario_ny)
print(data_inicio2_fuso_ny)
# Out:
# 2026-02-15 14:25:00-04:00

# %%
novo_inicio_fuso_ny = data_inicio2_fuso_ny + timedelta(hours=2)
print(novo_inicio_fuso_ny)
print(novo_inicio_fuso_ny.astimezone(fuso_horario_sp))
# Out:
# 2026-02-15 16:25:00-04:00
# 2026-02-15 17:25:00-03:00

# %% [markdown]
# Como alternativa, podemos usar o módulo `zoneinfo` para criar um objeto `tzinfo`. O módulo `zoneinfo` está disponível na biblioteca padrão do Python desde a versão 3.9. O módulo `zoneinfo` fornece uma classe `ZoneInfo` que pode ser usada para criar um objeto `tzinfo`. No exemplo abaixo, usamos o fuso horário de São Paulo. Observe que não precisamos passar um objeto `timedelta` para o construtor da classe `ZoneInfo`.

# %%
from zoneinfo import ZoneInfo
from datetime import datetime

fuso_sp = ZoneInfo("America/Sao_Paulo")
data_inicio = datetime(2026, 2, 15, 15, 25, tzinfo=fuso_sp)
print(data_inicio)
# Out:
# 2026-02-15 15:25:00-03:00

# %% [markdown]
# ### Conversão entre fusos horários
#
# Podemos converter um objeto datetime de um fuso horário para outro usando o método `astimezone()`.

# %%
fuso_ny = ZoneInfo("America/New_York")
print(data_inicio.astimezone(fuso_ny))
# Out:
# 2026-02-15 13:25:00-05:00

# %%
from zoneinfo import available_timezones

print(available_timezones())
# Out:
# {'Pacific/Marquesas', 'America/Managua', 'Asia/Damascus', 'Pacific/Kosrae', 'America/Monterrey', 'America/St_Vincent', 'Pacific/Efate', 'Asia/Rangoon', 'Africa/Algiers', 'America/Atka', 'America/Ensenada', 'Pacific/Norfolk', 'America/Pangnirtung', 'NZ-CHAT', 'Asia/Tomsk', 'Pacific/Fakaofo', 'Africa/Conakry', 'Australia/LHI', 'Pacific/Pitcairn', 'Australia/South', 'Australia/Brisbane', 'America/Moncton', 'Atlantic/South_Georgia', 'America/Guadeloupe', 'Asia/Hong_Kong', 'America/Santiago', 'America/Argentina/San_Luis', 'Asia/Ujung_Pandang', 'UCT', 'Europe/Isle_of_Man', 'America/Atikokan', 'Asia/Ashgabat', 'America/Cayenne', 'Etc/GMT0', 'America/North_Dakota/Beulah', 'Pacific/Tarawa', 'CST6CDT', 'US/Pacific', 'Asia/Baghdad', 'Asia/Nicosia', 'Etc/GMT+5', 'Atlantic/Azores', 'America/Grenada', 'America/Danmarkshavn', 'America/Fortaleza', 'Asia/Ashkhabad', 'Pacific/Easter', 'America/Vancouver', 'Asia/Taipei', 'Europe/Podgorica', 'Etc/GMT-14', 'America/Costa_Rica', 'America/Rankin_Inlet', 'Asia/Qyzylorda', 'America/Jamaica', 'Japan', 'Asia/Tel_Aviv', 'Europe/London', 'America/Caracas', 'Pacific/Honolulu', 'Asia/Aqtobe', 'America/Santarem', 'America/Winnipeg', 'Asia/Kashgar', 'Asia/Urumqi', 'America/Belem', 'America/Havana', 'Pacific/Port_Moresby', 'Europe/Amsterdam', 'Asia/Tbilisi', 'Australia/Queensland', 'America/Blanc-Sablon', 'Indian/Mayotte', 'Asia/Vientiane', 'Pacific/Gambier', 'Asia/Novokuznetsk', 'Europe/Athens', 'PST8PDT', 'Pacific/Galapagos', 'Asia/Thimbu', 'America/Indiana/Marengo', 'Etc/GMT-9', 'US/Aleutian', 'Antarctica/DumontDUrville', 'Africa/Tunis', 'Etc/GMT+0', 'Mexico/General', 'Asia/Kuala_Lumpur', 'Europe/Helsinki', 'Europe/Monaco', 'Pacific/Noumea', 'Asia/Oral', 'GMT+0', 'Africa/Casablanca', 'America/St_Barthelemy', 'Africa/Porto-Novo', 'Europe/Kirov', 'Africa/Johannesburg', 'Etc/GMT-3', 'Africa/Brazzaville', 'Africa/Kampala', 'US/Michigan', 'Asia/Famagusta', 'Asia/Irkutsk', 'Europe/Istanbul', 'Africa/Maseru', 'America/Martinique', 'Pacific/Truk', 'Atlantic/St_Helena', 'America/La_Paz', 'Indian/Mauritius', 'America/Mendoza', 'Africa/Freetown', 'GMT', 'Europe/Berlin', 'America/St_Lucia', 'Indian/Kerguelen', 'Africa/Ndjamena', 'America/St_Thomas', 'WET', 'America/Matamoros', 'America/Tijuana', 'Asia/Kuching', 'America/Kralendijk', 'Australia/West', 'America/Mexico_City', 'Africa/Timbuktu', 'Atlantic/Cape_Verde', 'Europe/Stockholm', 'America/Punta_Arenas', 'Asia/Yakutsk', 'America/Anguilla', 'Asia/Katmandu', 'Pacific/Nauru', 'Asia/Calcutta', 'Australia/Perth', 'America/St_Johns', 'Pacific/Wallis', 'Pacific/Tongatapu', 'Israel', 'Canada/Saskatchewan', 'Asia/Chongqing', 'America/Indiana/Indianapolis', 'Africa/Windhoek', 'Asia/Beirut', 'America/Yakutat', 'America/Chicago', 'Mexico/BajaNorte', 'Europe/San_Marino', 'Europe/Tirane', 'Etc/GMT+10', 'America/Merida', 'Europe/Oslo', 'America/Indiana/Knox', 'America/Halifax', 'Asia/Chita', 'Pacific/Chuuk', 'Asia/Novosibirsk', 'Africa/Juba', 'Europe/Kiev', 'Indian/Comoro', 'Etc/GMT-13', 'Pacific/Tahiti', 'America/Argentina/Cordoba', 'America/Kentucky/Monticello', 'US/Samoa', 'Navajo', 'Australia/Adelaide', 'Etc/GMT-4', 'America/Porto_Acre', 'Europe/Belfast', 'America/Argentina/San_Juan', 'Africa/Harare', 'Europe/Volgograd', 'Canada/Pacific', 'Australia/Yancowinna', 'America/Coral_Harbour', 'Asia/Srednekolymsk', 'Europe/Gibraltar', 'America/Montreal', 'Europe/Bratislava', 'America/Manaus', 'America/Argentina/Tucuman', 'America/Dawson', 'Etc/GMT+7', 'America/Toronto', 'Africa/Lagos', 'Etc/GMT-1', 'Pacific/Auckland', 'Antarctica/Palmer', 'America/Guayaquil', 'America/Virgin', 'America/Louisville', 'America/Boise', 'Europe/Belgrade', 'Australia/Melbourne', 'America/Cambridge_Bay', 'America/Miquelon', 'Etc/GMT+9', 'America/Rosario', 'Asia/Ulan_Bator', 'Europe/Vatican', 'Indian/Maldives', 'Asia/Singapore', 'Europe/Zagreb', 'Australia/Currie', 'HST', 'America/El_Salvador', 'America/Eirunepe', 'Africa/Libreville', 'America/Sao_Paulo', 'Africa/Ceuta', 'America/Nipigon', 'Canada/Central',  ...
