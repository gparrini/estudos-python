# %% [markdown]
# # Argumentos/Parâmetros da Função
#
# ### Estrutura:

# %% [raw]
# def minha_funcao(parametro1, parametro2, parametro3):
#     return parametro1 + parametro2 + parametro3

# %% [markdown]
# - Exemplo: nosso famoso print

# %%
vendas = 50
print('Produto', 'Iphone', 'Vendas', vendas)
# Out:
# Produto Iphone Vendas 50

# %% [markdown]
# - Só para mostrar o funcionamento, vamos criar uma função de soma

# %%
def minha_soma(num1, num2, num3):
    return num1 + num2 + num3


soma = minha_soma(10, 20, 0)
print(soma)
# Out:
# 30

# %% [markdown]
# - Vamos criar uma function com parâmetro
#
# Digamos que estamos criando um programa para categorizar os produtos de uma revendedora de bebidas.
#
# Cada produto tem um código. O tipo de produto é dado pelas 3 primeiras letras do código.
#
# Ex:<br>
# Vinho -> BEB12302<br>
# Cerveja -> BEB12043<br>
# Vodka -> BEB34501<br>
#
# Guaraná -> BSA11104<br>
# Coca -> BSA54301<br>
# Sprite -> BSA34012<br>
# Água -> BSA09871<br>
#
# Repare que bebidas não alcóolicas começam com BSA e bebidas alcoolicas começam com BEB.
#
# Crie um programa que analise uma lista de produtos e envie instruções para a equipe de estoque dizendo quais produtos devem ser enviados para a área de bebidas alcóolicas.

# %%
def ehalcoolico(bebida):
    bebida = bebida.upper()
    if 'BEB' in bebida:
        return True
    else:
        return False

produtos = ['beb46275','TFA23962','TFA64715','TFA69555','TFA56743','BSA45510','TFA44968','CAR75448','CAR23596','CAR13490','BEB21365','BEB31623','BSA62419','BEB73344','TFA20079','BEB80694','BSA11769','BEB19495','TFA14792','TFA78043','BSA33484','BEB97471','BEB62362','TFA27311','TFA17715','BEB85146','BEB48898','BEB79496','CAR38417','TFA19947','TFA58799','CAR94811','BSA59251','BEB15385','BEB24213','BEB56262','BSA96915','CAR53454','BEB75073']


# ler toda a lista
# checar se cada elemento da lista é beb
# enviar produto beb para a equipe

for produto in produtos:
    if ehalcoolico(produto):
        print(f'Enviar {produto} para setor de bebidas alcóolicas')

# %%
# =====================================================================
# EXPLICAÇÃO DAS DÚVIDAS DIRETAMENTE NOS COMENTÁRIOS DO CÓDIGO
# =====================================================================

# PERGUNTA 1: Por que dentro da função tem que colocar a variável 'bebida', 
# de onde ela veio e para que serve?
#
# RESPOSTA: A variável 'bebida' é o que chamamos de "parâmetro". Ela não 
# veio de nenhum lugar externo antes de você escrevê-la ali; você a 
# "inventou" na hora de criar a função. Ela serve apenas como um APELIDO 
# TEMPORÁRIO (um molde). É como dizer ao Python: "Tudo o que for jogado 
# dentro desta função, chame de 'bebida' para podermos trabalhar com 
# isso nas linhas seguintes".

def ehalcoolico(bebida):
    bebida = bebida.upper()
    
    # PERGUNTA 3: Qual o funcionamento de True e False dentro desse código?
    #
    # RESPOSTA: True (Verdadeiro) e False (Falso) são as respostas que a 
    # função devolve para o resto do código avisando se a condição foi 
    # atendida ou não.
    
    if 'BEB' in bebida:
        # Se o texto 'BEB' for encontrado, ela devolve True (Sim, é alcoólico).
        return True
    else:
        # Se não encontrar, ela devolve False (Não, não é alcoólico).
        return False

produtos = ['beb46275','TFA23962','TFA64715','TFA69555','TFA56743','BSA45510','TFA44968','CAR75448','CAR23596','CAR13490','BEB21365','BEB31623','BSA62419','BEB73344','TFA20079','BEB80694','BSA11769','BEB19495','TFA14792','TFA78043','BSA33484','BEB97471','BEB62362','TFA27311','TFA17715','BEB85146','BEB48898','BEB79496','CAR38417','TFA19947','TFA58799','CAR94811','BSA59251','BEB15385','BEB24213','BEB56262','BSA96915','CAR53454','BEB75073']


# ler toda a lista
# checar se cada elemento da lista é beb
# enviar produto beb para a equipe

# PERGUNTA 2: A segunda aparição da função quem tá dentro dela é a
