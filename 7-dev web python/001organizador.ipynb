# %%
import os
import re
import shutil

def organizar_por_nome_de_aula():
    diretorio_atual = os.getcwd()
    arquivo_txt = os.path.join(diretorio_atual, "00_MAPA_DE_RENOMEACAO.txt")

    if not os.path.exists(arquivo_txt):
        print("❌ Erro: O arquivo '00_MAPA_DE_RENOMEACAO.txt' não foi encontrado nesta pasta.")
        return

    def limpar_nome_sistema(nome):
        return re.sub(r'[\\/*?:"<>|]', "", nome).strip()

    regras = []
    with open(arquivo_txt, "r", encoding="utf-8") as f:
        for linha in f:
            match = re.search(r'\[Arquivo \d+\] -> (.*?)\s*\|\|\s*(.*?)\s*\|\|\s*(.*)', linha)
            if match:
                modulo = limpar_nome_sistema(match.group(1))
                submodulo = limpar_nome_sistema(match.group(2))
                nome_aula = limpar_nome_sistema(match.group(3))
                regras.append((modulo, submodulo, nome_aula))

    if not regras:
        print("❌ O arquivo de texto não possui dados válidos mapeados.")
        return

    # Lista apenas arquivos (ignora pastas ocultas que o Jupyter cria, como .ipynb_checkpoints)
    todos_arquivos = [f for f in os.listdir(diretorio_atual) if os.path.isfile(os.path.join(diretorio_atual, f))]
    
    # Ignora o txt do mapa e o próprio notebook
    arquivos_downloads = [
        f for f in todos_arquivos 
        if f not in ("00_MAPA_DE_RENOMEACAO.txt", "001organizador.ipynb")
    ]
    
    arquivos_downloads.sort(key=lambda x: os.path.getmtime(os.path.join(diretorio_atual, x)))

    if not arquivos_downloads:
        print("❌ Nenhum arquivo baixado encontrado para organizar.")
        return

    print(f"📦 Movendo e organizando {len(arquivos_downloads)} arquivos nas pastas...\n")

    for i, (modulo, submodulo, nome_aula) in enumerate(regras):
        if i >= len(arquivos_downloads):
            break

        nome_original = arquivos_downloads[i]
        caminho_original = os.path.join(diretorio_atual, nome_original)
        _, extensao = os.path.splitext(nome_original)

        pasta_destino = os.path.join(diretorio_atual, modulo, submodulo)
        os.makedirs(pasta_destino, exist_ok=True)

        novo_nome = f"{nome_aula}{extensao}"
        caminho_destino = os.path.join(pasta_destino, novo_nome)

        contador_duplicado = 1
        while os.path.exists(caminho_destino):
            novo_nome = f"{nome_aula}_({contador_duplicado}){extensao}"
            caminho_destino = os.path.join(pasta_destino, novo_nome)
            contador_duplicado += 1

        try:
            shutil.move(caminho_original, caminho_destino)
            print(f"✅ {modulo} \\ {submodulo} \\ {novo_nome}")
        except Exception as e:
            print(f"❌ Falha ao mover {nome_original}: {e}")

    print("\n🎉 Estrutura de pastas criada com perfeição! Tudo limpo e organizado.")

# No Jupyter, você pode simplesmente chamar a função assim:
organizar_por_nome_de_aula()
# Out:
# 📦 Movendo e organizando 199 arquivos nas pastas...
#
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 4. Configurações do Projeto e Instalação do Flask.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 5. Criando seu 1º Site com Flask.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 6. Explicando os Decorators e Páginas Estáticas e Dinâmicas.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 7. Criando templates HTML.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 8. Como funciona HTML.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 9. Base Visual das Páginas e Integrando arquivos HTML.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 10. Usando Bootstrap no nosso site.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 11. Puxando Informações de Forma Dinâmica do Python para o Site.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 12. Criando Barra de Navegação.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 13. Padronizando Links do Site.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 14. Criando Página de Login e Criar Conta.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 16. Segurança dos Formulários no Site.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 17. Adicionando Formulários no HTML.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 18. Aplicando Bootstrap nos Formulários.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 19. Liberando Método Post das Páginas.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 20. csrf token e Mensagem de Sucesso nos Formulários.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 21. Validações dos Campos dos Formulários.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 22. Banco de Dados para o Site.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 23. Criação das Tabelas do Banco de Dados.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 24. Relacionamento entre Posts e Usuários.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 26. Reestruturando o Projeto.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 27. Criando usuário no banco de dados com nosso formulário.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 28. Criptografando a Senha do Usuário.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 29. Criando validação Personalizada - Usuários Únicos.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 30. Login dos Usuários.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 31. Personalizando o Site para Usuários Logados.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 32. Bloquear Página para Usuários Visitantes.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 33. Redirecionamento Automático Inteligente.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 34. Editando a Página de Perfil - HTML e CSS.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 35. Carregando a imagem padrão de Perfil.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 36. Edição do Perfil.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 37. Funcionalidade do Formulário de Editar Perfil.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 38. Campo de Edição de Foto de Perfil.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 39. Salvar e Compactar Imagem no Banco de Dados.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 40. Revisando o Site e Adicionando Cursos no Form do Perfil.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 41. Editando o Campo Cursos do Banco de Dados.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 42. Exibindo os Cursos do Usuário.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 43. Preenchendo Lista de Usuários do Banco de Dados.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 44. Permitir a Criação de Post.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 45. Ajeitando a HomePage - Feed de Posts.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 46. Terminando Edição dos Posts.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 47. Uma Página para cada Post.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 48. Criando Edição do Post.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 49. Data de Criação, Editar e Excluir Post.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 50. Excluir Post.zip
# ✅ Módulo Sem Nome \ 1. Projeto 1 - Construindo um Site Completo do Zero com Flask \ 51. Método de Contagem de Posts.zip
# ✅ Módulo Sem Nome \ 2. Projeto 2 - Criação de Sites - Réplica do Pinterest em Flask \ 2. Como funciona o Desenvolvimento Web.zip
# ✅ Módulo Sem Nome \ 2. Projeto 2 - Criação de Sites - Réplica do Pinterest em Flask \ 18. Ajustando o Layout com um template.zip
# ✅ Módulo Sem Nome \ 2. Projeto 2 - Criação de Sites - Réplica do Pinterest em Flask \ 19. Implementanto Layout para todas as páginas.txt
# ✅ Módulo Sem Nome \ 2. Projeto 2 - Criação de Sites - Réplica do Pinterest em Flask \ 20. Ajustando a tela de Perfil.zip
# ✅ Módulo Sem Nome \ 2. Projeto 2 - Criação de Sites - Réplica do Pinterest em Flask \ 25. Ajuste arquivos efêmeros - imagens sumindo do site.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 5. Planejamento do Site.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 6. Iniciando o Projeto e Estrutura Inicial do Django.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 7. Criando seu 1º app do site.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 8. Migrations e Criando um SuperUser.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 9. Conectando um app novo no seu projeto.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 10. Explicando o arquivo settings.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 11. Criando o modelo do Filme - Adicionar tabelas no Banco de Dados.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 12. Adicionando o modelo do Filme no Administrador.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 13. Configurando pastas static e media.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 14. Criando uma página do nosso site.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 15. Criando seus templates e a estrutura de templates do site.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 16. Criando uma base em html e conectando aos templates.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 18. Editando a homepage.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 20. Passando parâmetros para as páginas html - Context.html
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 22. Criando uma View para cada Filme.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 23. Criando links dinâmicos no site.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 24. Modelo de Episódios e Chave Estrangeira.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 25. Vídeos em Tela Cheia e Listando Episódios no HTML.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 26. Passando variáveis personalizadas para as Views.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 27. Criando nossos Gerenciadores de Contexto - Variáveis para todos os templates.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 28. Contagem de Visualizações.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 30. Editando a Página Home dos Filmes.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 31. Edições Dinâmicas com Javascript e Filme em Destaque.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 32. Campo de Pesquisa.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 33. Criando nosso Usuário Personalizado e adaptando o projeto.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 34. Lista de Filmes Vistos pelo Usuário.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 35. Registrando Filme Visto de Forma Dinâmica.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 36. Bloqueio de Páginas apenas para usuários com login.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 39. Páginas de Login e Logout.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 40. Criar formulários personalizados e Criar Conta do Usuário.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 41. Redirecionamento Dinâmico de usuários.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 42. Editar Perfil e Mudar senha do usuário.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 47. Deploy do Site - Colocando o site no ar com Heroku.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 48. Banco de Dados online.zip
# ✅ Módulo Sem Nome \ 3. Projeto 3 - Criação de Sites com Django - Criando uma cópia do Netflix \ 49. Arquivos de Mídia em Produção no Heroku com Cloudinary.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 4. Criando o 1º link do nosso site.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 5. Carregando a 1ª página - FrontEnd x Backend.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 6. Criando várias páginas para o site.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 7. Uma base html - editando páginas de forma dinâmica.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 8. Arquivos static.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 10. Barra de navegação e links.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 11. Modelagem do Banco de Dados.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 12. Criando uma classe de um modelo no Banco de Dados.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 13. Criando todos os modelos.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 14. Migrations e Makemigrations - Edições no Banco de Dados.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 15. Área admin do Django - superuser e edições no admin.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 16. Campo de Imagem do Produto.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 17. Exibindo informações dinâmicas nos templates.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 18. Media no arquivo settings - Gestão de Imagens no Projeto.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 19. Criando os banners da homepage.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 20. Links dos banners - Links internos dinâmicos.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 21. Como filtrar objetos com o Django.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 22. Links com parâmetros dinâmicos.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 23. Filtros avançados em buscas - Loja.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 24. Tela de Detalhes do Produto - Links com parâmetros no html.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 25. Tabela de Cores e Aplicações de Queryset avançadas.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 26. Exibindo as cores de um produto.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 27. Filtrando tamanhos dos produtos de acordo com a cor selecionada.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 28. Funcionalidade de adicionar no carrinho - Formulários POST.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 29. Pegando informações de um formulário enviado.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 30. Criação do carrinho - Contextos Personalizados.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 31. Quantidade produto carrinho - usuário com login.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 32. Itens dentro do carrinho.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 33. Preço Total de Itens e de Pedidos - Funções Propriedade nos Models.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 34. Adicionar produto no carrinho.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 35. Edições de quantidade de produtos dentro do carrinho.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 36. Remover produtos do carrinho.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 37. Clientes Anônimos - Permitindo usuários visitantes comprarem.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 38. Visualização do Carrinho de clientes anônimos.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 39. Revisão dos views e contextos com ajustes para clientes anônimos.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 40. Mantendo os Cookies quando fecha o navegador - Cookies Efêmeros x Persistentes.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 41. Página de checkout e condição usuário autenticado no html.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 42. Terminando a página de checkout.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 43. Adicionar endereço - Mesmo view com métodos POST e GET.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 44. Categorias e Tipos na Barra de Navegação.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 45. Criação do slug para URLs dinâmicas.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 46. Filtros de tipo e categoria ao mesmo tempo.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 47. Filtros da Loja - Construção e Filtro de Preços.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 48. Filtros de tamanhos - método values_list e suas aplicações.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 49. Aplicando os filtros da nossa loja.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 50. Finalizando filtros da loja.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 51. Itens para ordenar produtos da loja.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 52. Javascript na página - Enviando parâmetro de URL na ordenação.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 53. Ordenar produtos - Order By.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 54. Ordenar produtos mais vendidos - Ordenações Personalizadas.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 55. Autenticação - Tela de Login e Criar Conta.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 56. Processo de Login do Usuário.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 57. Processo de criar conta.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 58. Logout e Testes de erros de criar conta.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 59. Login Required - Bloquear páginas apenas para usuários autenticados.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 60. Esqueci minha senha e Alteração de idioma e hora do admin.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 61. Meus Pedidos - Pedidos finalizados dos usuários.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 62. Tela da Minha Conta.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 63. Alterações de senha e dados pessoais do usuário.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 64. Finalizar pedido - Erros de finalização.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 65. Finalizar pedido - Ajustes pré implementação de pagamento.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 66. Integração com meio de pagamento - Configurações Mercado Pago.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 67. Criar preferência de pagamento - parâmetros de requisição e de resposta.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 68. Correções de erros e Conexão API Mercado Pago com as Views.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 69. Modelo de Pagamentos e Link de retorno do Mercado Pago.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 70. Finalizando a integração do Mercado Pago com nosso site.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 71. Finalização de pagamento do pedido.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 73. Configurando sistema de envio de emails no Django.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 74. Enviando email de compra bem sucedida.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 75. Criando uma equipe e página de Gerenciar Loja.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 76. Funcionalidades de Gerenciar a Loja.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 77. Exportar CSV do site.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 78. Importar o FrontEnd para o site.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 79. FrontEnd - Rodapé e head da página.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 80. FrontEnd - Barra de navegação.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 81. FrontEnd - Homepage.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 82. FrontEnd - Loja - Filtros Laterais.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 83. FrontEnd - Loja - Ordenação e Produtos.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 84. FrontEnd - Tela Produto - Informações do Produto.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 85. FrontEnd - Tela Produto - Produtos Similares.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 86. FrontEnd - Minha Conta.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 87. FrontEnd - Fazer Login e Criar Conta.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 88. FrontEnd - Meus Pedidos.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 89. FrontEnd - Carrinho.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 90. FrontEnd - Checkout.zip
# ✅ Módulo Sem Nome \ 4. Projeto 4 - Ecommerce Completo (com Django) \ 91. FrontEnd - Finalizando - Gerenciar Loja e Adicionar Endereço.crdownload
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 1. Apresentação do Projeto.crdownload
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 2. Como funciona o FastAPI - Vantagens.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 3. Instalação e como iniciar um projeto.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 4. Requisições, Endpoints e Roteadores.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 5. Criando rotas assíncronas.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 6. SQLAlchemy com FastAPI para criação de banco de dados.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 7. Criação dos models e tabelas do banco.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 8. Processo de migração de Banco de Dados - alembic.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 9. Rotas para criação de itens no sistema - usuarios.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 10. Gerenciamento de sessões do Banco de Dados.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 11. Criptografia de senhas com passlib e bcrypt.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 12. Schemas e padronizando entrada e saída de dados dos endpoints.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 13. Endpoint criar pedido.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 14. Endpoint de Login.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 15. Autenticação de Usuário - OAuth2.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 16. JWT Tokens - Segurança de API.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 17. Refresh Tokens.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 18. Bloqueando endpoints apenas para usuários autenticados.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 19. Autenticação por formulário nos docs do FastAPI.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 20. Cancelar pedidos e Bloqueio de múltiplas rotas por autenticação.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 21. Como implementar níveis de acesso no FastAPI.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 22. Lazyloaded no FastAPI e Exibindo informações do banco nas requisições.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 23. Endpoint para listar todos os pedidos.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 24. Adicionar item no pedido.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 25. Relationship e funções personalizadas nos Models.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 26. Remover itens pedido e lazyloaded em relationships no banco de dados.zip
# ✅ Módulo Sem Nome \ 5. Projeto 5 - FastAPI - API com Backend Completo - Projeto Delivery \ 27. Ver, Finalizar e Listar Pedidos.zip
#
# 🎉 Estrutura de pastas criada com perfeição! Tudo limpo e organizado.
