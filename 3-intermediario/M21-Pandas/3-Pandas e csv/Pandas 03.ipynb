# %% [markdown]
# # pandas e csv
#
# ## Resumo
#
# Quase sempre quando formos "ler" um arquivo csv, vamos usar o pandas. É prático e bem eficiente.
#
# ## Funcionamento

# %% [raw]
# Forma mais básica: (muitas vezes não usaremos a forma mais básica)
# dataframe = pd.read_csv(arquivo_com_extensao)

# %% [markdown]
# - Vamos ler um arquivo real, com a Base de Dados de Vendas da Empresa "Contoso"

# %%
import pandas as pd

vendas_df = pd.read_csv('Contoso - Cadastro Produtos.csv')

print(vendas_df)
# Out:
#                                                                 Nome da Marca;Tipo;Custo Unitario;Preco Unitario;ID Produto;Categoria
# Contoso;Econômico;10        69;20                                                 96;873;Acessório para Computador
# Contoso;Econômico;6         63;13;879;Acessório para Computador                                                NaN
#                             63;13;880;Acessório para Computador                                                NaN
#                             63;13;881;Acessório para Computador                                                NaN
#                             63;13;882;Acessório para Computador                                                NaN
# ...                                                                                                            ...
# Southridge Video;Regular;82 77;179                                                               99;1602;Filme DVD
# ...

# %%
import pandas as pd

vendas_df = pd.read_csv('Contoso - Cadastro Produtos.csv')

vendas_df
# Out:
#                                                                 Nome da Marca;Tipo;Custo Unitario;Preco Unitario;ID Produto;Categoria
# Contoso;Econômico;10        69;20                                                 96;873;Acessório para Computador
# Contoso;Econômico;6         63;13;879;Acessório para Computador                                                NaN
#                             63;13;880;Acessório para Computador                                                NaN
#                             63;13;881;Acessório para Computador                                                NaN
#                             63;13;882;Acessório para Computador                                                NaN
# ...                                                                                                            ...
# Southridge Video;Regular;82 77;179                                                               99;1602;Filme DVD
# ...

# %%
#csv as celulas sao separadas por ',' e nessa planilha os dados estão separados por ';' logo devemos especificar isso
import pandas as pd

vendas_df = pd.read_csv('Contoso - Cadastro Produtos.csv', sep= ';') #também pode colar o caminho do arquivo

vendas_df
# Out:
#          Nome da Marca       Tipo Custo Unitario Preco Unitario  ID Produto  \
# 0              Contoso  Econômico          10,69          20,96         873
# 1              Contoso  Econômico           6,63             13         879
# 2              Contoso  Econômico           6,63             13         880
# 3              Contoso  Econômico           6,63             13         881
# 4              Contoso  Econômico           6,63             13         882
# ...                ...        ...            ...            ...         ...
# 1685  Southridge Video    Regular          82,77         179,99        1602
# 1686  Southridge Video    Regular          73,57         159,99        1606
# 1687  Southridge Video    Regular          82,77         179,99        1607
# 1688  Southridge Video    Regular          73,57         159,99        1611
# 1689  Southridge Video    Regular          82,77         179,99        1612
#
#                       Categoria
# ...
