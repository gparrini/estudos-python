# %% [markdown]
# # Alterações de Variáveis
#
# Estrutura:
#
# - variavel = variavel + outro_valor
#
# ou então
#
# - variavel += outro_valor

# %% [markdown]
# Exemplo: vamos adicionar às variáveis criadas o Produto IPad, 500 vendas

# %%
faturamento1 = 3000
faturamento1 = faturamento1 + 1000
print(faturamento1)
#ou então

faturamento2 = 700
faturamento2 += 500
print(faturamento2)
# Out:
# 4000
# 1200

# %%
lista = ['mac', 'iphone']
vendas = [100, 200]
#adicionando IPad na lista
lista = lista + ['Ipad']
print(lista)

#ou

lista.append('Ipad')
print(lista)
# Out:
# ['mac', 'iphone', 'Ipad']
# ['mac', 'iphone', 'Ipad', 'Ipad']

# %%
soma_vendas = 300
#adicionando na soma a quantidade de IPad
soma_vendas = 3000
soma_vendas = soma_vendas + 1000
print(soma_vendas)
# Out:
# 4000

# %%
email = 'Esse mês vendemos um total de {} produtos, sendo:\n{} unidades de {}\n{} unidades de {}'.format(soma_vendas, vendas[0], lista[0], vendas[1], lista[1])
#adicionando no fim do texto o Ipad
email = email + f'\n{500} unidasdes de Ipad'




print(email)
# Out:
# Esse mês vendemos um total de 4000 produtos, sendo:
# 100 unidades de mac
# 200 unidades de iphone
# 500 unidasdes de Ipad
