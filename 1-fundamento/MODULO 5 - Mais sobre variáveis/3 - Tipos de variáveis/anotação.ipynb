# %%
faturamento = 1500
custo = 500
lucro = faturamento - custo
print("o faturamento da loja foi de " + str(faturamento))
print("o custo da loja foi de " + str(custo))
print("o lucro da loja foi de " + str(lucro))
# Out:
# o faturamento da loja foi de 1500
# o custo da loja foi de 500
# o lucro da loja foi de 1000

# %%
faturamento = 1500
custo = 500
lucro = faturamento - custo
print('o faturamento da loja foi {}. o custo da loja foi {}. o lucro da loja foi {}'.format(faturamento, custo, lucro))
# Out:
# o faturamento da loja foi 1500. o custo da loja foi 500. o lucro da loja foi 1000

# %%
#Metodo f-string
faturamento = 1500
custo = 500
lucro = faturamento - custo

print(f"o faturamento da loja foi de {faturamento}. o custo da loja foi de {custo}. o lucro da loja foi de {lucro}")
# Out:
# o faturamento da loja foi de 1500. o custo da loja foi de 500. o lucro da loja foi de 1000

# %%
#Mudança tipo de variável

faturamento = int(input("Insira o faturamento"))
custo = int(input("Insira o custo"))

lucro = faturamento - custo
print(lucro)

# str - muda paa uma string
# int - muda para um inteiro
# float - muda para um numero com casas decimais
# Out:
# 1200
