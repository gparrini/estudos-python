# %% [markdown]
# # for + if
#
# ### Estrutura:

# %% [raw]
# for item in lista:
#     if condicao:
#         faça alguma coisa
#     else:
#         outra coisa

# %% [markdown]
# Digamos que a gente esteja analisando a meta de vendas de vários funcionários de uma empresa. A meta de vendas é de 1000 reais em 1 dia.
#
# Temos uma lista com as vendas de todos os funcionários e quero calcular qual o % de pessoas que bateram a meta.

# %%
vendas = [1200, 300, 800, 1500, 1900, 2750, 400, 20, 23, 70, 90, 80, 1100, 999, 900, 880, 870, 50, 1111, 120, 300, 450, 800]
meta = 1000

for i in range(vendas):
    if vendas[i] > meta:
        print(len(vendas[i] > meta))
    else:
        print('nenhum vendedor bateu a meta')

# %%
vendas = [1200, 300, 800, 1500, 1900, 2750, 400, 20, 23, 70, 90, 80, 1100, 999, 900, 880, 870, 50, 1111, 120, 300, 450, 800]
meta = 1000

qtde_bateu_meta = 0

for venda in vendas:
    if venda >= meta:
        qtde_bateu_meta += 1

qtde_funcionarios = len(vendas)

print(f'O percentual de pessoas que bateram a meta foi de {qtde_bateu_meta / qtde_funcionarios:.1%}')
# Out:
# O percentual de pessoas que bateram a meta foi de 26.1%

# %%
#no trecho do código surgiu 'venda' sendo que não criei, e procurei uma explicação para isso:

vendas = [1200, 300, 800, 1500, 1900, 2750, 400, 20, 23, 70, 90, 80, 1100, 999, 900, 880, 870, 50, 1111, 120, 300, 450, 800]
meta = 1000

qtde_bateu_meta = 0

# O Python "cria" a variável 'venda' aqui na linha abaixo:
for venda in vendas:
    if venda >= meta:
        qtde_bateu_meta += 1

a explicação é:

#Imagine o for como um "gerente de estoque" que pega uma caixa por vez de uma prateleira.

#Como o Python entende isso:
vendas (no plural): É a sua lista completa, o conjunto de todos os dados.

venda (no singular): É o nome que você escolheu para representar "o item da vez".

#Quando você escreve for venda in vendas:, você está dizendo ao Python:

"Pegue o primeiro valor de vendas, coloque dentro de uma variável chamada venda e execute o código abaixo."
"Depois, pegue o segundo valor, coloque na mesma variável venda e repita, até acabar a lista."

Anatomia do For
A estrutura sempre segue este padrão:

#for variável_temporária in iterável (lista, tupla, etc) :

#Variável temporária: Você pode dar qualquer nome (pode ser venda, item, x, numero). O Python vai atribuir o valor atual da lista a esse nome a cada rodada do loop.

#Iterável: É de onde o Python vai tirar os dados (neste caso, a sua lista vendas).
