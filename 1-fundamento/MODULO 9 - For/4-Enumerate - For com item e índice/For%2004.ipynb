# %% [markdown]
# # Enumerate
#
# ### Estrutura:
#
# O enumerate permite que você percorra uma lista e ao mesmo tempo tenha em uma variável o índice daquele item.
#
# - for normalmente

# %% [raw]
# for item in lista:
#     resto do código

# %%
funcionarios = ['Maria', 'José', 'Antônio', 'João', 'Francisco', 'Ana', 'Luiz', 'Paulo', 'Carlos', 'Manoel', 'Pedro', 'Francisca', 'Marcos', 'Raimundo', 'Sebastião', 'Antônia', 'Marcelo', 'Jorge', 'Márcia', 'Geraldo', 'Adriana', 'Sandra', 'Luis']
for funcionario in funcionarios:
    print(funcionario)
# Out:
# Maria
# José
# Antônio
# João
# Francisco
# Ana
# Luiz
# Paulo
# Carlos
# Manoel
# Pedro
# Francisca
# Marcos
# Raimundo
# Sebastião
# Antônia
# Marcelo
# Jorge
# Márcia
# Geraldo
# Adriana
# Sandra
# Luis

# %% [raw]
# for i, item in enumerate(lista):
#     resto do código

# %%
funcionarios = ['Maria', 'José', 'Antônio', 'João', 'Francisco', 'Ana']

for funcionario in enumerate(funcionarios): #ele numerou e guardou a informação nome e numero dentro da nova variavel funcionário
    print(f' é o funcionário {funcionario}')
# Out:
#  é o funcionário (0, 'Maria')
#  é o funcionário (1, 'José')
#  é o funcionário (2, 'Antônio')
#  é o funcionário (3, 'João')
#  é o funcionário (4, 'Francisco')
#  é o funcionário (5, 'Ana')

# %%
funcionarios = ['Maria', 'José', 'Antônio', 'João', 'Francisco', 'Ana', 'Luiz', 'Paulo', 'Carlos', 'Manoel', 'Pedro', 'Francisca', 'Marcos', 'Raimundo', 'Sebastião', 'Antônia', 'Marcelo', 'Jorge', 'Márcia', 'Geraldo', 'Adriana', 'Sandra', 'Luis']

for i, funcionario in enumerate(funcionarios):
    print(f'{i} é o funcionário {funcionario}')

#A vírgula no for i, funcionario diz ao Python: "Pegue o primeiro número e guarde no i, e pegue o nome e guarde em funcionario".
# Out:
# 0 é o funcionário Maria
# 1 é o funcionário José
# 2 é o funcionário Antônio
# 3 é o funcionário João
# 4 é o funcionário Francisco
# 5 é o funcionário Ana
# 6 é o funcionário Luiz
# 7 é o funcionário Paulo
# 8 é o funcionário Carlos
# 9 é o funcionário Manoel
# 10 é o funcionário Pedro
# 11 é o funcionário Francisca
# 12 é o funcionário Marcos
# 13 é o funcionário Raimundo
# 14 é o funcionário Sebastião
# 15 é o funcionário Antônia
# 16 é o funcionário Marcelo
# 17 é o funcionário Jorge
# 18 é o funcionário Márcia
# 19 é o funcionário Geraldo
# 20 é o funcionário Adriana
# 21 é o funcionário Sandra
# 22 é o funcionário Luis

# %% [markdown]
# ### Exemplo Prático
#
# Vamos pegar um exemplo de nível mínimo de estoque. Em uma fábrica você tem vários produtos e não pode deixar que os produtos fiquem em falta. Para isso, foi definido uma quantidade mínima de estoque que os produtos precisam ter:
#
# Identifique quais produtos estão abaixo do nível mínimo de estoque.

# %%
estoque = [1200, 300, 800, 1500, 1900, 2750, 400, 20, 23, 70, 90, 80, 1100, 999, 900, 880, 870, 50, 1111, 120, 300, 450, 800]
produtos = ['coca', 'pepsi', 'guarana', 'skol', 'brahma', 'agua', 'del valle', 'dolly', 'red bull', 'cachaça', 'vinho tinto', 'vodka', 'vinho branco', 'tequila', 'champagne', 'gin', 'guaracamp', 'matte', 'leite de castanha', 'leite', 'jurupinga', 'sprite', 'fanta']
nivel_minimo = 50

for i, qtde in enumerate(estoque): #enumere estoque para cada i e qtde
    if qtde < nivel_minimo:
        print(f'{produtos[i]} está abaixo do nível mínimo. Temos apenas {qtde} unidades')
# Out:
# dolly está abaixo do nível mínimo. Temos apenas 20 unidades
# red bull está abaixo do nível mínimo. Temos apenas 23 unidades

# %%
'''por que la no pint o qtd não é qtde[1]?

estoque = [1200, 300, 800, 1500, 1900, 2750, 400, 20, 23, 70, 90, 80, 1100, 999, 900, 880, 870, 50, 1111, 120, 300, 450, 800]

produtos = ['coca', 'pepsi', 'guarana', 'skol', 'brahma', 'agua', 'del valle', 'dolly', 'red bull', 'cachaça', 'vinho tinto', 'vodka', 'vinho branco', 'tequila', 'champagne', 'gin', 'guaracamp', 'matte', 'leite de castanha', 'leite', 'jurupinga', 'sprite', 'fanta']

nivel_minimo = 50

A resposta curta é: qtde já é o número solto, enquanto produtos ainda é a lista inteira.

Para entender melhor, vamos olhar para o que cada variável guarda no exato momento em que o print acontece:

1. O que é o qtde?
Quando você faz o for, o Python vai até a lista estoque, pega um único número e guarda na variável temporária qtde.
Ou seja, na rodada em que o estoque está baixo, qtde vale exatamente 20.
Como 20 é apenas um número inteiro (e não uma lista), você não pode usar colchetes nele. Se você tentasse escrever qtde[i], o Python daria um erro, pois seria o mesmo que tentar fazer 20[7], o que não faz sentido.

2. O que é o produtos?
A variável produtos não está no for. O for só está desmanchando a lista estoque.
Portanto, produtos continua sendo a lista inteira com todos os nomes de bebidas. Como é uma lista inteira, você precisa usar os colchetes [i] para dizer ao Python: "Vá na lista de produtos e pegue apenas o nome que está na gaveta número i".

A prova real: qtde é igual a estoque[i]
Se você quisesse usar os colchetes para a quantidade, você teria que chamar a lista inteira do estoque, assim:
print(f'Temos apenas {estoque[i]} unidades')

Isso funcionaria perfeitamente! Mas perceba que não precisamos fazer isso, porque o enumerate já fez o favor de pegar o estoque[i] e dar um apelido mais fácil para ele: qtde.
'''
